# %% [markdown]
# ## Sentence-level split preprocessing
# This notebook preprocesses textual documents by splitting them into sentence-level units. Each line is treated as a separate context unit and segmented into sentences using spaCy, with a custom component to prevent incorrect splits at common abbreviations. The output is saved as CSV files with one sentence per row for downstream analysis.
#
# The documents were translated from Russian to English using the DeepL API and manually corrected by the author where necessary to ensure accuracy for analysis.

# %%
# !python -m spacy download en_core_web_sm

# %%
from pathlib import Path
from utils.prepare_abdico_sentences import process_directory
input_dir = Path('Translated_Docs')
output_dir = Path('ABDICO_CSVs')

process_directory(input_dir, output_dir)
# Out:
# Created: ABDICO_CSVs/docs/скоростные вычисления_high-speed_computing_sentences.csv
# Created: ABDICO_CSVs/docs/быстрый старт хакера_hacker's_quick_start_sentences.csv
# Created: ABDICO_CSVs/docs/быстрый старт исследователя_researcher's_quick_start_sentences.csv
# Created: ABDICO_CSVs/docs/дух старой школы_old-school_spirit_sentences.csv
# Created: ABDICO_CSVs/docs/misc/ТЗ автоматизация группового тестирования в криптопанели_TechSpec_automation_of_group_testing_in_crypto_panel_sentences.csv
# Created: ABDICO_CSVs/docs/misc/ТЗ проверка инжектора_Injector_inspection_TechSpec_sentences.csv
# Created: ABDICO_CSVs/docs/misc/ТЗ статус проверки в криптопанели_TechSpec_verification_status_in_the_crypto_panel_sentences.csv
# Created: ABDICO_CSVs/docs/misc/ТЗ автоматизация тестирования криптов_TechSpec_automation_of_crypto_testing_sentences.csv
# Created: ABDICO_CSVs/docs/misc/tor_sentences.csv
# ...
